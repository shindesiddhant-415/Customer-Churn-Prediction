# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Telco_customer_churn.xlsx")

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
#  17  Online Security    7043 non-null   str
#  18  Online Backup      7043 non-null   str
#  19  Device Protection  7043 non-null   str
#  20  Tech Support       7043 non-null   str
#  21  Streaming TV       7043 non-null   str
#  22  Streaming Movies   7043 non-null   str
#  23  Contract           7043 non-null   str
#  24  Paperless Billing  7043 non-null   str
#  25  Payment Method     7043 non-null   str
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   str
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   str
# dtypes: float64(3), int64(6), object(1), str(23)
# memory usage: 1.8+ MB

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Tenure Months'], bins = 30, kde = True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer Count')
plt.title('Distribution of Tenure Months vs no of customer')
plt.savefig("images/churn_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df['Tenure Months'].max()
df['Tenure Months'].min()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn Label', y='Tenure Months', data=df)
plt.title('Churn vs Tenure Months')
plt.savefig("images/Tenure_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Monthly Charges'], bins = 30, kde = True)
plt.xlabel('Monthly Charges')
plt.ylabel('Customer Count')
plt.title('Distribution of monthly Charges vs no of customer')
plt.savefig("images/monthly_charges_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df['Monthly Charges'].min()
# Out:
# np.float64(18.25)

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn Label', y='Monthly Charges', data=df)
plt.title('Churn vs Monthly Charges')
plt.savefig("images/churn_vs_monthly_charges.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df[df['Churn Label'] == 'Yes'] ['Monthly Charges'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label'] == 'No'] ['Monthly Charges'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# <StringArray>
# ['Month-to-month', 'Two year', 'One year']
# Length: 3, dtype: str

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x = 'Contract', hue = 'Churn Label', data=df)
plt.xlabel('Contract')
plt.ylabel('count')
plt.title('Contract vs count')
plt.savefig("images/contract_vs_churn.png", dpi=300, bbox_inches="tight")

# %%
df['Payment Method'].unique()
# Out:
# <StringArray>
# [             'Mailed check',          'Electronic check',
#  'Bank transfer (automatic)',   'Credit card (automatic)']
# Length: 4, dtype: str

# %%
plt.figure(figsize=(8,6))
sns.countplot(x = 'Payment Method', hue = 'Churn Label', data=df)
plt.xlabel('Payment Method')
plt.ylabel('count')
plt.title('Payment Method vs count')
plt.savefig("images/payment_method_vs_churn.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str

# %%
plt.figure(figsize=(8,6))
sns.countplot(x = 'Tech Support', hue = 'Churn Label', data=df)
plt.xlabel('Tech Support')
plt.ylabel('count')
plt.title('Tech Support vs count')
plt.savefig("images/tech_support_vs_churn.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
avg_tenure = df.groupby('Churn Label')['Tenure Months'].mean()
print(avg_tenure)
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
#  17  Online Security    7043 non-null   str
#  18  Online Backup      7043 non-null   str
#  19  Device Protection  7043 non-null   str
#  20  Tech Support       7043 non-null   str
#  21  Streaming TV       7043 non-null   str
#  22  Streaming Movies   7043 non-null   str
#  23  Contract           7043 non-null   str
#  24  Paperless Billing  7043 non-null   str
#  25  Payment Method     7043 non-null   str
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   str
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   str
# dtypes: float64(3), int64(6), object(1), str(23)
# memory usage: 1.8+ MB

# %%
numerical_cols = ['Tenure Months', 'Monthly Charges', 'Churn Value', 'Churn Score', 'CLTV']
correlation_matrix = df[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.savefig("images/correlation_matrix.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
contract_churn = pd.crosstab(df['Contract'], df['Churn Label'], normalize= 'index')
print(contract_churn)
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# **Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
#  17  Online Security    7043 non-null   str
#  18  Online Backup      7043 non-null   str
#  19  Device Protection  7043 non-null   str
#  20  Tech Support       7043 non-null   str
#  21  Streaming TV       7043 non-null   str
#  22  Streaming Movies   7043 non-null   str
#  23  Contract           7043 non-null   str
#  24  Paperless Billing  7043 non-null   str
#  25  Payment Method     7043 non-null   str
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   str
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   str
# dtypes: float64(3), int64(6), object(1), str(23)
# memory usage: 1.8+ MB

# %%
display(df['Total Charges'])
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# 2234    0
# 2438    0
# 2568    0
# 2667    0
# 2856    0
# 4331    0
# 4687    0
# 5104    0
# 5719    0
# 6772    0
# 6840    0
# Name: Tenure Months, dtype: int64

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# (11,)

# %%
df['Total Charges'] = df['Total Charges'].fillna(0)
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
#  17  Online Security    7043 non-null   str
#  18  Online Backup      7043 non-null   str
#  19  Device Protection  7043 non-null   str
#  20  Tech Support       7043 non-null   str
#  21  Streaming TV       7043 non-null   str
#  22  Streaming Movies   7043 non-null   str
#  23  Contract           7043 non-null   str
#  24  Paperless Billing  7043 non-null   str
#  25  Payment Method     7043 non-null   str
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   float64
#  28  Churn Label        7043 non-null   str
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   str
# dtypes: float64(4), int64(6), str(23)
# memory usage: 1.8 MB

# %%
columns_to_drop = [
    'CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long',
    'Latitude', 'Longitude', 'Churn Label', 'Churn Score', 'CLTV', 'Churn Reason'
]

# %%
df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   str
#  1   Senior Citizen     7043 non-null   str
#  2   Partner            7043 non-null   str
#  3   Dependents         7043 non-null   str
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   str
#  6   Multiple Lines     7043 non-null   str
#  7   Internet Service   7043 non-null   str
#  8   Online Security    7043 non-null   str
#  9   Online Backup      7043 non-null   str
#  10  Device Protection  7043 non-null   str
#  11  Tech Support       7043 non-null   str
#  12  Streaming TV       7043 non-null   str
#  13  Streaming Movies   7043 non-null   str
#  14  Contract           7043 non-null   str
#  15  Paperless Billing  7043 non-null   str
#  16  Payment Method     7043 non-null   str
#  17  Monthly Charges    7043 non-null   float64
#  18  Total Charges      7043 non-null   float64
#  19  Churn Value        7043 non-null   int64
# dtypes: float64(2), int64(2), str(16)
# memory usage: 1.1 MB

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded.head()
# Out:
#    Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0              2            53.85         108.15            1         True
# 1              2            70.70         151.65            1        False
# 2              8            99.65         820.50            1        False
# 3             28           104.80        3046.05            1        False
# 4             49           103.70        5036.30            1         True
#
#    Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0               False        False           False               True
# 1               False        False            True               True
# 2               False        False            True               True
# 3               False         True            True               True
# 4               False        False            True               True
#
#    Multiple Lines_No phone service  ...  Streaming TV_No internet service  \
# 0                            False  ...                             False
# 1                            False  ...                             False
# 2                            False  ...                             False
# 3                            False  ...                             False
# 4                            False  ...                             False
#
#    Streaming TV_Yes  Streaming Movies_No internet service  \
# 0             False                                 False
# 1             False                                 False
# 2              True                                 False
# 3              True                                 False
# 4              True                                 False
#
#    Streaming Movies_Yes  Contract_One year  Contract_Two year  \
# 0                 False              False              False
# 1                 False              False              False
# 2                  True              False              False
# 3                  True              False              False
# 4                  True              False              False
#
#    Paperless Billing_Yes  Payment Method_Credit card (automatic)  \
# 0                   True                                   False
# 1                   True                                   False
# 2                   True                                   False
# 3                   True                                   False
# 4                   True                                   False
#
#    Payment Method_Electronic check  Payment Method_Mailed check
# 0                            False                         True
# 1                             True                        False
# 2                             True                        False
# 3                             True                        False
# 4                            False                        False
#
# [5 rows x 31 columns]

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   str
#  1   Senior Citizen     7043 non-null   str
#  2   Partner            7043 non-null   str
#  3   Dependents         7043 non-null   str
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   str
#  6   Multiple Lines     7043 non-null   str
#  7   Internet Service   7043 non-null   str
#  8   Online Security    7043 non-null   str
#  9   Online Backup      7043 non-null   str
#  10  Device Protection  7043 non-null   str
#  11  Tech Support       7043 non-null   str
#  12  Streaming TV       7043 non-null   str
#  13  Streaming Movies   7043 non-null   str
#  14  Contract           7043 non-null   str
#  15  Paperless Billing  7043 non-null   str
#  16  Payment Method     7043 non-null   str
#  17  Monthly Charges    7043 non-null   float64
#  18  Total Charges      7043 non-null   float64
#  19  Churn Value        7043 non-null   int64
# dtypes: float64(2), int64(2), str(16)
# memory usage: 1.1 MB

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  ...  Streaming TV_No internet service  \
# 0                               False  ...                             False
# 1                               False  ...                             False
# 2                               False  ...                             False
# 3                               False  ...                             False
# 4                               False  ...                             False
# ...                               ...  ...                               ...
# 7038                            False  ...                              True
# 7039                            False  ...                             False
# 7040                            False  ...                             False
# 7041                             True  ...                             False
# 7042                            False  ...                             False
#
#       Streaming TV_Yes  Streaming Movies_No internet service  \
# 0                False                                 False
# 1                False                                 False
# 2                 True                                 False
# 3                 True                                 False
# 4                 True                                 False
# ...                ...                                   ...
# 7038             False                                  True
# 7039              True                                 False
# 7040              True                                 False
# 7041             False                                 False
# 7042              True                                 False
#
#       Streaming Movies_Yes  Contract_One year  Contract_Two year  \
# 0                    False              False              False
# 1                    False              False              False
# 2                     True              False              False
# 3                     True              False              False
# 4                     True              False              False
# ...                    ...                ...                ...
# 7038                 False              False               True
# 7039                  True               True              False
# 7040                  True               True              False
# 7041                 False              False              False
# 7042                  True              False               True
#
#       Paperless Billing_Yes  Payment Method_Credit card (automatic)  \
# 0                      True                                   False
# 1                      True                                   False
# 2                      True                                   False
# 3                      True                                   False
# 4                      True                                   False
# ...                     ...                                     ...
# 7038                   True                                   False
# 7039                   True                                   False
# 7040                   True                                    True
# 7041                   True                                   False
# 7042                   True                                   False
#
#       Payment Method_Electronic check  Payment Method_Mailed check
# 0                               False                         True
# 1                                True                        False
# 2                                True                        False
# 3                                True                        False
# 4                               False                        False
# ...                               ...                          ...
# 7038                            False                        False
# 7039                            False                         True
# 7040                            False                        False
# 7041                             True                        False
# 7042                            False                        False
#
# [7043 rows x 31 columns]

# %%
x = df_encoded.drop('Churn Value', axis = 1)
y = df_encoded['Churn Value']

# %%
x.shape
y.shape
# Out:
# (7043,)

# %%
print(x)
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# 1                  False        False            True               True
# 2                  False        False            True               True
# 3                  False         True            True               True
# 4                  False        False            True               True
# ...                  ...          ...             ...                ...
# 7038               False        False           False               True
# 7039               False         True            True               True
# 7040               False         True            True               True
# 7041               False         True            True              False
# 7042               False        False           False               True
#
#       Multiple Lines_No phone service  Multiple Lines_Yes  ...  \
# 0                               False               False  ...
# 1                               False               False  ...
# 2                               False                True  ...
# 3                               False                True  ...
# 4                               False                True  ...
# ...                               ...                 ...  ...
# 7038                            False               False  ...
# 7039                            False                True  ...
# 7040                            False                True  ...
# 7041                             True               False  ...
# 7042                            False               False  ...
#
#       Streaming TV_No internet service  Streaming TV_Yes  \
# 0                                False             False
# 1                                False             False
# 2                                False              True
# 3                                False              True
# 4                                False              True
# ...                                ...               ...
# 7038                              True             False
# 7039                             False              True
# 7040                             False              True
# 7041                             False             False
# 7042                             False              True
#
#       Streaming Movies_No internet service  Streaming Movies_Yes  \
# 0                                    False                 False
# 1                                    False                 False
# 2                                    False                  True
# 3                                    False                  True
# 4                                    False                  True
# ...                                    ...                   ...
# 7038                                  True                 False
# 7039                                 False                  True
# 7040                                 False                  True
# 7041                                 False                 False
# 7042                                 False                  True
#
#       Contract_One year  Contract_Two year  Paperless Billing_Yes  \
# 0                 False              False                   True
# 1                 False              False                   True
# 2                 False              False                   True
# 3                 False              False                   True
# 4                 False              False                   True
# ...                 ...                ...                    ...
# 7038              False               True                   True
# 7039               True              False                   True
# 7040               True              False                   True
# 7041              False              False                   True
# 7042              False               True                   True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                      False                            False
# 1                                      False                             True
# 2                                      False                             True
# 3                                      False                             True
# 4                                      False                            False
# ...                                      ...                              ...
# 7038                                   False                            False
# 7039                                   False                            False
# 7040                                    True                            False
# 7041                                   False                             True
# 7042                                   False                            False
#
#       Payment Method_Mailed check
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 7038                        False
# 7039                         True
# 7040                        False
# 7041                        False
# 7042                        False
#
# [7043 rows x 30 columns]

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %% [markdown]
# **Machine Learning Implementation**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.shape
# Out:
# (5634, 30)

# %%
x_test.shape
# Out:
# (1409, 30)

# %%
y_train.shape
# Out:
# (5634,)

# %%
y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(x_test)

# %%
y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1409,))

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.7856635911994322

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
print(cm)
# Out:
# [[902 107]
#  [195 205]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# **Approach 1 - Handle class imbalance**

# %%
rf_balanced = RandomForestClassifier(n_estimators = 100, random_state = 42, class_weight = 'balanced')
rf_balanced.fit(x_train, y_train)
y_pred_balanced = rf_balanced.predict(x_test)
accuracy_balanced = accuracy_score(y_test, y_pred_balanced)
cm_balanced = confusion_matrix(y_test, y_pred_balanced)

print(accuracy_balanced, cm_balanced)
print(classification_report(y_test, y_pred_balanced))
# Out:
# 0.7885024840312278 [[835 174]
#  [124 276]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1009
#            1       0.61      0.69      0.65       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.76      0.75      1409
# weighted avg       0.80      0.79      0.79      1409

# %% [markdown]
# **Approach 2- Hyperparameter tuning**

# %%
rf_tuned = RandomForestClassifier(n_estimators = 200, random_state = 42, class_weight = 'balanced', max_depth = 10)
rf_tuned.fit(x_train, y_train)
y_pred_tuned = rf_tuned.predict(x_test)

print(classification_report(y_test, y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1009
#            1       0.56      0.78      0.65       400
#
#     accuracy                           0.76      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.76      0.77      1409

# %% [markdown]
# **Approach 3 Feature importance analysis**

# %%
import pandas as pd
feature_importance = pd.DataFrame({
    'features': x.columns,
    'importance': rf_tuned.feature_importances_
})
feature_importance = feature_importance.sort_values(by = 'importance', ascending = False)
print(feature_importance.tail(15))
# Out:
#                                   features  importance
# 12     Online Security_No internet service    0.013612
# 15                       Online Backup_Yes    0.012750
# 3                              Gender_Male    0.012651
# 11                     Internet Service_No    0.012234
# 9                       Multiple Lines_Yes    0.011633
# 20        Streaming TV_No internet service    0.011210
# 4                       Senior Citizen_Yes    0.011155
# 23                    Streaming Movies_Yes    0.010250
# 21                        Streaming TV_Yes    0.009372
# 17                   Device Protection_Yes    0.008894
# 27  Payment Method_Credit card (automatic)    0.008861
# 29             Payment Method_Mailed check    0.008724
# 14       Online Backup_No internet service    0.008398
# 7                        Phone Service_Yes    0.004094
# 8          Multiple Lines_No phone service    0.003521

# %%
x_selected = x.drop(['Phone Service_Yes', 'Multiple Lines_No phone service'], axis = 1)

# %%
x_train_sel, x_test_sel, y_train_sel, y_test_sel = train_test_split(x_selected, y, test_size = 0.2, random_state = 42)

# %%
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_selected.fit(x_train_sel,y_train_sel)
y_pred_selected=rf_selected.predict(x_test_sel)

print (classification_report(y_test_sel, y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82      1009
#            1       0.56      0.78      0.65       400
#
#     accuracy                           0.77      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.77      0.78      1409

# %% [markdown]
# **Approach combinantion of trees and depth**

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
n_estimators_list = [100, 200, 300, 400, 500]
max_depth_list = [5, 10, 15]
result = []

for n_trees in n_estimators_list:
    for depth in max_depth_list:
        rf = RandomForestClassifier(n_estimators=n_trees, max_depth=depth, random_state=42, class_weight= 'balanced')
        rf.fit(x_train, y_train)
        y_pred = rf.predict(x_test)
        accuracy = accuracy_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        result.append(
            {
                'Trees': n_trees,
                'Depth': depth,
                'Accuracy': accuracy,
                'Recall': recall,
                'Precision': precision,
                'F1': f1
            }
        )
    result_df = pd.DataFrame(result)
    result_df = result_df.sort_values(by=['Recall', 'Accuracy'], ascending=False)
    print(result_df)
# Out:
#    Trees  Depth  Accuracy  Recall  Precision        F1
# 0    100      5  0.740241  0.8200   0.527331  0.641879
# 1    100     10  0.768630  0.7775   0.567518  0.656118
# 2    100     15  0.789212  0.7375   0.605749  0.665163
#    Trees  Depth  Accuracy  Recall  Precision        F1
# 3    200      5  0.743790  0.8200   0.531605  0.645034
# 0    100      5  0.740241  0.8200   0.527331  0.641879
# 1    100     10  0.768630  0.7775   0.567518  0.656118
# 4    200     10  0.764372  0.7775   0.561372  0.651992
# 2    100     15  0.789212  0.7375   0.605749  0.665163
# 5    200     15  0.784954  0.7325   0.599182  0.659168
#    Trees  Depth  Accuracy  Recall  Precision        F1
# 3    200      5  0.743790  0.8200   0.531605  0.645034
# 0    100      5  0.740241  0.8200   0.527331  0.641879
# 6    300      5  0.741661  0.8175   0.529126  0.642436
# 7    300     10  0.765791  0.7875   0.562500  0.656250
# 1    100     10  0.768630  0.7775   0.567518  0.656118
# 4    200     10  0.764372  0.7775   0.561372  0.651992
# 2    100     15  0.789212  0.7375   0.605749  0.665163
# 5    200     15  0.784954  0.7325   0.599182  0.659168
# 8    300     15  0.787793  0.7250   0.605428  0.659841
#     Trees  Depth  Accuracy  Recall  Precision        F1
# 9     400      5  0.744500  0.8200   0.532468  0.645669
# 3     200      5  0.743790  0.8200   0.531605  0.645034
# 0     100      5  0.740241  0.8200   0.527331  0.641879
# 6     300      5  0.741661  0.8175   0.529126  0.642436
# 10    400     10  0.766501  0.7875   0.563506  0.656934
# 7     300     10  0.765791  0.7875   0.562500  0.656250
# 1     100     10  0.768630  0.7775   0.567518  0.656118
# 4     200     10  0.764372  0.7775   0.561372  0.651992
# 2     100     15  0.789212  0.7375   0.605749  0.665163
# 5     200     15  0.784954  0.7325   0.599182  0.659168
# 11    400     15  0.789212  0.7250   0.607966  0.661345
# 8     300     15  0.787793  0.7250   0.605428  0.659841
#     Trees  Depth  Accuracy  Recall  Precision        F1
# 9     400      5  0.744500  0.8200   0.532468  0.645669
# 3     200      5  0.743790  0.8200   0.531605  0.645034
# 0     100      5  0.740241  0.8200   0.527331  0.641879
# 12    500      5  0.742370  0.8175   0.529984  0.643068
# 6     300      5  0.741661  0.8175   0.529126  0.642436
# 10    400     10  0.766501  0.7875   0.563506  0.656934
# 7     300     10  0.765791  0.7875   0.562500  0.656250
# 13    500     10  0.765791  0.7875   0.562500  0.656250
# 1     100     10  0.768630  0.7775   0.567518  0.656118
# 4     200     10  0.764372  0.7775   0.561372  0.651992
# 2     100     15  0.789212  0.7375   0.605749  0.665163
# 5     200     15  0.784954  0.7325   0.599182  0.659168
# 14    500     15  0.790632  0.7250   0.610526  0.662857
# 11    400     15  0.789212  0.7250   0.607966  0.661345
# 8     300     15  0.787793  0.7250   0.605428  0.659841

# %%
from sklearn.model_selection import cross_val_score
final_rf = RandomForestClassifier(n_estimators=500, max_depth=10, random_state=42, class_weight='balanced')

# %%
cv_accuracy = cross_val_score(final_rf, x, y, cv=5, scoring='accuracy')

# %%
cv_accuracy
# Out:
# array([0.7523066 , 0.78353442, 0.75017743, 0.7734375 , 0.76491477])

# %%
cv_accuracy.mean()
# Out:
# np.float64(0.7648741451061358)

# %%
cv_recall = cross_val_score(final_rf, x, y, cv=5, scoring='recall')

# %%
cv_recall
# Out:
# array([0.72994652, 0.80748663, 0.76203209, 0.78074866, 0.72922252])

# %%
cv_recall.mean()
# Out:
# np.float64(0.7618872847701109)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
y_prob = rf_tuned.predict_proba(x_test)

# %%
churn_prob = y_prob[:, 1]
fpr, tpr, threshold = roc_curve(y_test, churn_prob)
auc_score = roc_auc_score(y_test, churn_prob)
print(auc_score)
# Out:
# 0.8554806739345887

# %% [markdown]
# **Customer Segmentation**

# %%
segmentation_data = pd.DataFrame({
    'Tenure Months': x_test['Tenure Months'],
    'Monthly Charges': x_test['Monthly Charges'],
    'Total Charges': x_test['Total Charges'],
    'churn_prob': churn_prob
})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  churn_prob
# 185              15            85.90        1269.55    0.723061
# 2715             18            56.80        1074.65    0.338499
# 3825              2            20.00          40.90    0.256871
# 1807              6            84.20         519.15    0.834921
# 132              40           104.80        4131.95    0.505337
# ...             ...              ...            ...         ...
# 6366             66           104.90        6891.45    0.156226
# 315              19            86.00        1532.45    0.737251
# 2439              2            90.35         190.50    0.772457
# 5002             68           110.20        7467.50    0.110795
# 1161             30            99.70        2967.35    0.786201
#
# [1409 rows x 4 columns]

# %% [markdown]
# Implementation of K means

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(segmentation_data)
print(scaled_data[:5])
# Out:
# [[-0.69631406  0.6691038  -0.45048988  1.07589936]
#  [-0.57429095 -0.31419848 -0.53600108 -0.19657171]
#  [-1.22508089 -1.55768728 -0.98955267 -0.46666858]
#  [-1.0623834   0.61166002 -0.77972336  1.44603416]
#  [ 0.32054522  1.30774342  0.80537089  0.35547517]]

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 16):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
    plt.figure(figsize = (8,6))
plt.plot(range(1, 16), wcss, marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.savefig("images/elbow_method.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  churn_prob
# 185              15            85.90        1269.55    0.723061
# 2715             18            56.80        1074.65    0.338499
# 3825              2            20.00          40.90    0.256871
# 1807              6            84.20         519.15    0.834921
# 132              40           104.80        4131.95    0.505337
# ...             ...              ...            ...         ...
# 6366             66           104.90        6891.45    0.156226
# 315              19            86.00        1532.45    0.737251
# 2439              2            90.35         190.50    0.772457
# 5002             68           110.20        7467.50    0.110795
# 1161             30            99.70        2967.35    0.786201
#
# [1409 rows x 4 columns]

# %%
segmentation_data['Cluster'] = clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  churn_prob  Cluster
# 185              15            85.90        1269.55    0.723061        0
# 2715             18            56.80        1074.65    0.338499        2
# 3825              2            20.00          40.90    0.256871        2
# 1807              6            84.20         519.15    0.834921        0
# 132              40           104.80        4131.95    0.505337        1
# ...             ...              ...            ...         ...      ...
# 6366             66           104.90        6891.45    0.156226        1
# 315              19            86.00        1532.45    0.737251        0
# 2439              2            90.35         190.50    0.772457        0
# 5002             68           110.20        7467.50    0.110795        1
# 1161             30            99.70        2967.35    0.786201        0
#
# [1409 rows x 5 columns]

# %%
cluster_summary = segmentation_data.groupby('Cluster').mean()

# %%
cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  churn_prob
# Cluster
# 0            11.069470        73.357221     896.221298    0.707417
# 1            58.760563        90.658685    5328.899648    0.252512
# 2            32.497706        32.994725    1089.846101    0.151658

# %%
cluster_names = {
    0: 'Budget Loyal Customers',
    1: 'High Risk New Customers',
    2: 'Loyal Premium Customers'
}

# %%
segmentation_data['Cluster Segment'] = segmentation_data['Cluster'].map(cluster_names)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  churn_prob  Cluster  \
# 185              15            85.90        1269.55    0.723061        0
# 2715             18            56.80        1074.65    0.338499        2
# 3825              2            20.00          40.90    0.256871        2
# 1807              6            84.20         519.15    0.834921        0
# 132              40           104.80        4131.95    0.505337        1
# ...             ...              ...            ...         ...      ...
# 6366             66           104.90        6891.45    0.156226        1
# 315              19            86.00        1532.45    0.737251        0
# 2439              2            90.35         190.50    0.772457        0
# 5002             68           110.20        7467.50    0.110795        1
# 1161             30            99.70        2967.35    0.786201        0
#
#               Cluster Segment
# 185    Budget Loyal Customers
# 2715  Loyal Premium Customers
# 3825  Loyal Premium Customers
# 1807   Budget Loyal Customers
# 132   High Risk New Customers
# ...                       ...
# 6366  High Risk New Customers
# 315    Budget Loyal Customers
# 2439   Budget Loyal Customers
# 5002  High Risk New Customers
# 1161   Budget Loyal Customers
#
# [1409 rows x 6 columns]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Monthly Charges', y='churn_prob', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
plt.savefig("images/customer_segmentation_monthly_charges.png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Tenure Months', y='churn_prob', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
plt.savefig("images/customer_segmentation_tenure.png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Total Charges', y='churn_prob', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
plt.savefig("images/customer_segmentation_total_charges.png", dpi=300, bbox_inches="tight")

# %%
# ===========================================
# Final Model Evaluation
# ===========================================

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

# Predictions
y_pred = rf_tuned.predict(x_test)
y_prob = rf_tuned.predict_proba(x_test)[:, 1]

# Evaluation Metrics
print("="*50)
print("FINAL MODEL PERFORMANCE")
print("="*50)

print(f"Accuracy  : {accuracy_score(y_test, y_pred):.4f}")
print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-Score  : {f1_score(y_test, y_pred):.4f}")
print(f"ROC-AUC   : {roc_auc_score(y_test, y_prob):.4f}")

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# ==================================================
# FINAL MODEL PERFORMANCE
# ==================================================
# Accuracy  : 0.7821
# Precision : 0.5924
# Recall    : 0.7450
# F1-Score  : 0.6600
# ROC-AUC   : 0.8576
#
# Confusion Matrix
# [[804 205]
#  [102 298]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.59      0.74      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409
